# %% [markdown]
# # **Project Name**

# %% [markdown]
# ****Amazon Prime Video Content Analysis using Exploratory Data Analysis (EDA)****

# %% [markdown]
# ##### **Project Type**    - **EDA**
# ##### **Contribution**    - **Individual**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# ## Project Summary
#
# In the rapidly growing digital entertainment industry, streaming platforms such as Amazon Prime Video play a critical role in delivering diverse content to global audiences. With increasing competition among streaming services, it has become essential for companies to analyze content trends, audience preferences, and production strategies using data-driven methods. This project focuses on performing Exploratory Data Analysis (EDA) on Amazon Prime Video content data to uncover valuable insights that can support business decision-making and content strategy development.
#
# The dataset used in this project consists of two primary files: titles.csv and credits.csv. The titles dataset contains information about movies and television shows available on Amazon Prime Video, including attributes such as title name, show type (movie or TV show), release year, runtime, genres, production countries, IMDb ratings, and popularity scores. The credits dataset provides details about actors and directors associated with each title, including their roles and character names. Together, these datasets offer a comprehensive view of content distribution and creative participation on the platform.
#
# The primary objective of this project is to analyze and understand the structure, distribution, and characteristics of Amazon Prime Video content. Through systematic data cleaning, transformation, and visualization, the project aims to answer key analytical questions related to content dominance, genre popularity, rating patterns, production trends, and actor involvement. The insights derived from this analysis can assist stakeholders in identifying successful content strategies and optimizing future content investments.
#
# The project begins with data loading and understanding, where the datasets are examined for structure, missing values, duplicates, and data types. Data cleaning techniques are applied to handle missing values, remove duplicates, and correct inconsistencies. Special attention is given to categorical variables such as genres and production countries, which may contain multiple values. These fields are transformed into structured formats to support accurate analysis.
#
# Exploratory Data Analysis plays a central role in this project. Multiple visualizations are created to explore relationships between different variables and uncover patterns in the data. Visualizations include distribution plots for show types, release year trends, genre distributions, runtime patterns, and rating comparisons between IMDb and TMDb scores. Additional analysis is performed to identify the most frequent actors and directors, providing insights into participation trends within the platform.
#
# Statistical analysis techniques are also applied to understand correlations between numerical variables such as runtime, ratings, and popularity scores. Outlier detection methods are used to identify extreme values that may influence analysis results. These statistical insights enhance the reliability and interpretability of the findings.
#
# The results of this project provide meaningful insights into the composition and evolution of Amazon Prime Video's content library. For example, the analysis helps determine whether movies dominate over television shows, identify the most common genres, track growth in content production over time, and understand how ratings influence popularity. These insights are valuable for content creators, marketing teams, and business stakeholders who aim to enhance user engagement and maximize return on investment.
#
# Overall, this project demonstrates the practical application of data analysis techniques using Python libraries such as Pandas, NumPy, Matplotlib, and Seaborn. It highlights the importance of data-driven decision-making in the streaming industry and showcases how exploratory analysis can uncover actionable insights that support strategic planning and content optimization.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Subhamdgm/Module_2_Project_EDA

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# ## Problem Statement
#
# With the rapid expansion of streaming platforms, Amazon Prime Video has significantly increased its content library to meet the demands of diverse audiences. As the volume of movies and TV shows grows, it becomes essential to analyze the available content to understand distribution patterns, genre popularity, production trends, and audience engagement.
#
# The objective of this project is to perform Exploratory Data Analysis (EDA) on Amazon Prime Video content data to uncover meaningful insights about the platform’s content library. The dataset includes information about titles such as movies and TV shows, along with their ratings, genres, runtime, release years, and associated actors and directors.
#
# Through this analysis, the project aims to answer the following key questions:
#
# • What is the distribution of Movies versus TV Shows on Amazon Prime Video?
# • Which genres dominate the platform’s content library?
# • How has the number of titles changed over time?
# • Which production countries contribute the most content?
# • What are the relationships between IMDb ratings, popularity, and runtime?
# • Which actors and directors appear most frequently across titles?
#
# By addressing these questions, this project seeks to identify important content trends and performance indicators that can support better decision-making in content production, marketing strategies, and platform growth.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# ## Business Objective
#
# The primary business objective of this project is to analyze Amazon Prime Video content data to generate actionable insights that support data-driven decision-making in the streaming industry.
#
# As streaming platforms continue to expand their content libraries, understanding patterns in content distribution, genre popularity, production trends, and audience engagement becomes essential for maintaining competitive advantage. This project aims to explore and analyze available data to identify meaningful trends that can help optimize content strategy and improve user satisfaction.
#
# The specific business objectives of this project include:
#
# • To analyze the distribution of Movies and TV Shows available on Amazon Prime Video.
#
# • To identify the most frequently occurring genres and understand content diversity across the platform.
#
# • To study trends in content production over the years and evaluate the growth of the content library.
#
# • To examine the relationship between ratings, popularity, and runtime to understand factors influencing audience engagement.
#
# • To analyze production countries to identify major contributors to the platform's content.
#
# • To identify frequently appearing actors and directors to understand participation trends.
#
# The insights derived from this analysis will help stakeholders such as content creators, business analysts, and marketing teams make informed decisions regarding content production, promotion strategies, and investment planning.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
#setting seaborn style
sns.set(style="whitegrid")
#display all column
pd.set_option('display.max_columns',None)

# %%
# #mount Google drive
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
try:
  # titles=pd.read_csv('/content/drive/MyDrive/Amazon_Prime_EDA/titles.csv')
  # credits=pd.read_csv('/content/drive/MyDrive/Amazon_Prime_EDA/credits.csv')
  titles=pd.read_csv("titles.csv")
  credits=pd.read_csv("credits.csv")
  print("Dataset loaded successfully")
except FileNotFoundError:
  print("Dataset not found. Please check the file path.")
except Exception as e:
  print(f"An error occurred: {e}")
# Out:
# Dataset loaded successfully

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
# Display first 5 rows of titles dataset
print("Titles Dataset - First 5 Rows")
display(titles.head())

# Display first 5 rows of credits dataset
print("\nCredits Dataset - First 5 Rows")
display(credits.head())
# Out:
# Titles Dataset - First 5 Rows
#         id                        title   type  \
# 0  ts20945            The Three Stooges   SHOW
# 1  tm19248                  The General  MOVIE
# 2  tm82253  The Best Years of Our Lives  MOVIE
# 3  tm83884              His Girl Friday  MOVIE
# 4  tm56584            In a Lonely Place  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  During America’s Civil War, Union spies steal ...          1926
# 2  It's the hope that sustains the spirit of ever...          1946
# 3  Hildy, the journalist former wife of newspaper...          1940
# 4  An aspiring actress begins to suspect that her...          1950
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1               NaN       78
# 2               NaN      171
# 3               NaN       92
# 4               NaN       94
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
# Titles dataset shape
print("Titles Dataset Shape:", titles.shape)

print("Number of Rows in Titles Dataset:", titles.shape[0])
print("Number of Columns in Titles Dataset:", titles.shape[1])

print("\n--------------------------------------\n")

# Credits dataset shape
print("Credits Dataset Shape:", credits.shape)

print("Number of Rows in Credits Dataset:", credits.shape[0])
print("Number of Columns in Credits Dataset:", credits.shape[1])
# Out:
# Titles Dataset Shape: (9871, 15)
# Number of Rows in Titles Dataset: 9871
# Number of Columns in Titles Dataset: 15
#
# --------------------------------------
#
# Credits Dataset Shape: (124235, 5)
# Number of Rows in Credits Dataset: 124235
# Number of Columns in Credits Dataset: 5

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
print("Titles Dataset Info:")
print("\n")

titles.info()

print("\n--------------------------------------\n")

print("Credits Dataset Info:")
print("\n")

credits.info()
# Out:
# Titles Dataset Info:
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9871 entries, 0 to 9870
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9871 non-null   object
#  1   title                 9871 non-null   object
#  2   type                  9871 non-null   object
#  3   description           9752 non-null   object
#  4   release_year          9871 non-null   int64
#  5   age_certification     3384 non-null   object
#  6   runtime               9871 non-null   int64
#  7   genres                9871 non-null   object
#  8   production_countries  9871 non-null   object
#  9   seasons               1357 non-null   float64
#  10  imdb_id               9204 non-null   object
#  11  imdb_score            8850 non-null   float64
#  12  imdb_votes            8840 non-null   float64
#  13  tmdb_popularity       9324 non-null   float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
titles_duplicates = titles.duplicated().sum()

print("Number of duplicate rows in Titles dataset:", titles_duplicates)

print("\n--------------------------------------\n")

# Check duplicate rows in credits dataset
credits_duplicates = credits.duplicated().sum()

print("Number of duplicate rows in Credits dataset:", credits_duplicates)
# Out:
# Number of duplicate rows in Titles dataset: 3
#
# --------------------------------------
#
# Number of duplicate rows in Credits dataset: 56

# %% [markdown]
# ##Remove the Duplicates from the datsets

# %%
# Remove duplicates from titles dataset
titles = titles.drop_duplicates()

# Remove duplicates from credits dataset
credits = credits.drop_duplicates()

print("Duplicate rows removed successfully!")
# Out:
# Duplicate rows removed successfully!

# %%
titles_duplicates = titles.duplicated().sum()
credits_duplicates = credits.duplicated().sum()
print("Number of duplicate rows in Titles dataset:", titles_duplicates)
print("Number of duplicate rows in Credits dataset:", credits_duplicates)
# Out:
# Number of duplicate rows in Titles dataset: 0
# Number of duplicate rows in Credits dataset: 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
# Missing values in titles dataset
print("Missing Values in Titles Dataset:\n")

titles_missing = titles.isnull().sum()

print(titles_missing)

print("\n--------------------------------------\n")

# Missing values in credits dataset
print("Missing Values in Credits Dataset:\n")

credits_missing = credits.isnull().sum()

print(credits_missing)
# Out:
# Missing Values in Titles Dataset:
#
# id                         0
# title                      0
# type                       0
# description              119
# release_year               0
# age_certification       6484
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 8511
# imdb_id                  667
# imdb_score              1021
# imdb_votes              1031
# tmdb_popularity          547
# tmdb_score              2080
# dtype: int64
#
# --------------------------------------
#
# Missing Values in Credits Dataset:
#
# person_id        0
# id               0
# name             0
# character    16277
# role             0
# dtype: int64

# %%
# Missing Values Visualization - Titles Dataset


# Calculate missing values
titles_missing = titles.isnull().sum()

# Filter only columns with missing values
titles_missing = titles_missing[titles_missing > 0]

# Plot bar chart
plt.figure(figsize=(12,6))

titles_missing.sort_values().plot(
    kind='barh'
)

plt.title("Missing Values Count - Titles Dataset")

plt.xlabel("Number of Missing Values")

plt.ylabel("Columns")

plt.show()


# Missing Values Visualization - Credits Dataset


# Calculate missing values
credits_missing = credits.isnull().sum()

# Filter only columns with missing values
credits_missing = credits_missing[credits_missing > 0]

# Plot bar chart
plt.figure(figsize=(12,6))

credits_missing.sort_values().plot(
    kind='barh'
)

plt.title("Missing Values Count - Credits Dataset")

plt.xlabel("Number of Missing Values")

plt.ylabel("Columns")

plt.show()

# %% [markdown]
# ### Why did I pick the specific chart?
#
# A bar plot was selected because it clearly displays the number of missing values in each column, making it easy to compare columns and identify which variables require data cleaning.
#
# ### What are the insight(s) found from the chart?
#
# The visualization shows that several columns in the titles dataset, such as age_certification, seasons, imdb_score, imdb_votes, and tmdb_score, contain significant missing values. In the credits dataset, the character column contains a large number of missing values compared to other columns.
#
# ### Will the gained insights help creating a positive business impact?
#
# Yes. Identifying columns with missing values helps in selecting appropriate data cleaning strategies, which improves data quality and ensures reliable analysis. Proper data handling leads to accurate insights that support better decision-making. Poor handling of missing data could lead to misleading results and negatively impact business strategies.

# %% [markdown]
# ### What did you know about your dataset?
#
#
# After performing initial data exploration and examining the datasets using functions such as head(), shape(), info(), and missing value analysis, several important observations were made about the datasets.
#
# The project consists of two datasets: **titles dataset** and **credits dataset**. The titles dataset contains detailed information about movies and TV shows available on Amazon Prime Video, including attributes such as title name, type (movie or TV show), release year, runtime, genres, production countries, IMDb ratings, and popularity scores. The credits dataset contains information about actors and directors associated with each title, including person ID, title ID, actor/director name, character name, and role type.
#
# The titles dataset contains both categorical and numerical variables. Categorical variables include type, age_certification, genres, and production_countries, while numerical variables include release_year, runtime, imdb_score, imdb_votes, tmdb_popularity, and tmdb_score. Similarly, the credits dataset mainly contains categorical variables such as name, character, and role.
#
# During the missing value analysis, it was observed that several columns contain missing values. In the titles dataset, columns such as **age_certification**, **seasons**, **imdb_score**, **imdb_votes**, **tmdb_score**, **tmdb_popularity**, **imdb_id**, and **description** contain missing values. Among these, the **seasons** column has the highest number of missing values, which is expected because many records represent movies where seasons are not applicable. The **age_certification** column also contains a large number of missing values, indicating that certification information may not be available for all titles.
#
# In the credits dataset, the **character** column contains a significant number of missing values, which may indicate that character names were not recorded for some actors or entries.
#
# Duplicate value checking confirmed that duplicate records were either minimal or removed to ensure data integrity. Overall, the dataset contains rich and valuable information suitable for performing detailed exploratory data analysis.
#
# These observations highlight the importance of performing proper data cleaning and preprocessing before moving forward with visualization and statistical analysis to ensure accurate and reliable insights.

# %% [markdown]
# Answer Here

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns

print("columns in the titles dataset:")
print(titles.columns)

print("\n--------------------------------------\n")

print("columns in the credits dataset")
print(credits.columns)
# Out:
# columns in the titles dataset:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')
#
# --------------------------------------
#
# columns in the credits dataset
# Index(['person_id', 'id', 'name', 'character', 'role'], dtype='object')

# %%
# Dataset Describe
print("description of columns in the titles dataset:")
print(titles.describe())

print("\n--------------------------------------\n")
print("description of columns in the credits dataset:")
print(credits.describe())
# Out:
# description of columns in the titles dataset:
#        release_year      runtime      seasons   imdb_score    imdb_votes  \
# count   9868.000000  9868.000000  1357.000000  8847.000000  8.837000e+03
# mean    2001.345561    85.979124     2.791452     5.976534  8.536485e+03
# std       25.792295    33.515714     4.148958     1.344028  4.592768e+04
# min     1912.000000     1.000000     1.000000     1.100000  5.000000e+00
# 25%     1996.000000    65.000000     1.000000     5.100000  1.180000e+02
# 50%     2014.000000    89.000000     1.000000     6.100000  4.640000e+02
# 75%     2018.000000   102.000000     3.000000     6.900000  2.237000e+03
# max     2022.000000   549.000000    51.000000     9.900000  1.133692e+06
#
#        tmdb_popularity   tmdb_score
# count      9321.000000  7788.000000
# mean          6.912168     5.984117
# std          30.008727     1.518040
# min           0.000011     0.800000
# 25%           1.234000     5.100000
# 50%           2.537000     6.000000
# ...

# %% [markdown]
# ### Variables Description
#
# > ## Variables Description
#
# ### Titles Dataset Variables
#
# | Column Name | Description |
# |-------------|-------------|
# | id | Unique identifier for each title in the dataset |
# | title | Name of the movie or TV show |
# | type | Indicates whether the content is a Movie or TV Show |
# | description | Short summary or description of the content |
# | release_year | Year in which the title was released |
# | age_certification | Age rating assigned to the content (e.g., PG, R) |
# | runtime | Duration of the movie or episode in minutes |
# | genres | List of genres associated with the content |
# | production_countries | Countries where the content was produced |
# | seasons | Number of seasons (applicable only to TV Shows) |
# | imdb_id | Unique identifier of the title on IMDb |
# | imdb_score | IMDb rating score of the content |
# | imdb_votes | Number of votes received on IMDb |
# | tmdb_popularity | Popularity score on TMDb platform |
# | tmdb_score | TMDb rating score of the content |

# %% [markdown]
# ### Credits Dataset Variables
#
# | Column Name | Description |
# |-------------|-------------|
# | person_id | Unique identifier of each actor or director |
# | id | Unique identifier linking the credit to a title |
# | name | Name of the actor or director |
# | character | Name of the character played by the actor |
# | role | Indicates whether the person is an ACTOR or DIRECTOR |

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

print("Unique Values Count - Titles Dataset\n")

for col in titles.columns:
    print(f"{col} : {titles[col].nunique()} unique values")

print("\n--------------------------------------\n")

print("Unique Values Count - Credits Dataset\n")

for col in credits.columns:
    print(f"{col} : {credits[col].nunique()} unique values")
# Out:
# Unique Values Count - Titles Dataset
#
# id : 9868 unique values
# title : 9737 unique values
# type : 2 unique values
# description : 9734 unique values
# release_year : 110 unique values
# age_certification : 11 unique values
# runtime : 207 unique values
# genres : 2028 unique values
# production_countries : 497 unique values
# seasons : 32 unique values
# imdb_id : 9201 unique values
# imdb_score : 86 unique values
# imdb_votes : 3650 unique values
# tmdb_popularity : 5325 unique values
# tmdb_score : 89 unique values
#
# --------------------------------------
#
# Unique Values Count - Credits Dataset
#
# person_id : 80508 unique values
# id : 8861 unique values
# name : 79758 unique values
# character : 71097 unique values
# role : 2 unique values

# %% [markdown]
# ## Observations from Unique Values
#
# After analyzing the number of unique values in each variable, several important observations were made about the dataset:
#
# 1. The **type** column contains only **2 unique values**, indicating that the dataset consists of two main categories: **Movies** and **TV Shows**. This variable will play a key role in categorical comparisons and visualizations.
#
# 2. The **release_year** column contains **110 unique values**, showing that the dataset spans a wide range of years. This makes it suitable for trend analysis over time.
#
# 3. The **age_certification** column contains **11 unique values**, representing different certification categories such as PG, R, etc. This variable can be used to analyze audience targeting trends.
#
# 4. The **runtime** column contains **207 unique values**, indicating a wide variation in content duration. This variable is suitable for distribution and outlier analysis.
#
# 5. The **genres** column contains **2028 unique combinations**, suggesting that titles may belong to multiple genres. This column will require transformation (such as splitting or exploding values) before performing genre-based analysis.
#
# 6. The **production_countries** column contains **497 unique values**, indicating a diverse set of production locations. This suggests strong geographical diversity in content production.
#
# 7. The **imdb_score** and **tmdb_score** columns contain **86 and 89 unique values**, respectively, making them suitable for rating distribution and correlation analysis.
#
# 8. In the credits dataset, the **role** column contains only **2 unique values**, confirming that the dataset includes **ACTOR** and **DIRECTOR** roles.
#
# 9. The **name** and **character** columns contain a very large number of unique values, indicating that the dataset includes many unique actors and characters. These columns will be useful for identifying frequently appearing actors or directors.
#
# 10. The high number of unique values in columns such as **title**, **genres**, and **production_countries** suggests that the dataset is highly diverse and suitable for performing comprehensive exploratory data analysis.
#
# Overall, the dataset contains a mix of low-cardinality and high-cardinality variables, making it suitable for both categorical and numerical analysis. Proper preprocessing of multi-value columns such as genres and production_countries will be required before visualization.

# %%
print("Data Types - Titles Dataset\n")

print(titles.dtypes)

print("\n--------------------------------------\n")

print("Data Types - Credits Dataset\n")

print(credits.dtypes)
# Out:
# Data Types - Titles Dataset
#
# id                       object
# title                    object
# type                     object
# description              object
# release_year              int64
# age_certification        object
# runtime                   int64
# genres                   object
# production_countries     object
# seasons                 float64
# imdb_id                  object
# imdb_score              float64
# imdb_votes              float64
# tmdb_popularity         float64
# tmdb_score              float64
# dtype: object
#
# --------------------------------------
#
# Data Types - Credits Dataset
#
# person_id     int64
# id           object
# name         object
# character    object
# role         object
# dtype: object

# %%
# ============================================
# Categorizing Variables
# ============================================

# Numerical columns (Titles Dataset)

numerical_cols = [
    'release_year',
    'runtime',
    'seasons',
    'imdb_score',
    'imdb_votes',
    'tmdb_popularity',
    'tmdb_score'
]


# Categorical columns (Titles Dataset)

categorical_cols = [
    'type',
    'age_certification',
    'genres',
    'production_countries'
]


print("Numerical Columns:\n", numerical_cols)

print("\n--------------------------------------\n")

print("Categorical Columns:\n", categorical_cols)
# Out:
# Numerical Columns:
#  ['release_year', 'runtime', 'seasons', 'imdb_score', 'imdb_votes', 'tmdb_popularity', 'tmdb_score']
#
# --------------------------------------
#
# Categorical Columns:
#  ['type', 'age_certification', 'genres', 'production_countries']

# %% [markdown]
# ## 3. ***Data Wrangling***

# %%
#since we saw missing values so we are ready to handle the missing values
# Missing Values/Null Values Count
# Missing values in titles dataset
print("Missing Values in Titles Dataset:\n")

titles_missing = titles.isnull().sum()

print(titles_missing)

print("\n--------------------------------------\n")

# Missing values in credits dataset
print("Missing Values in Credits Dataset:\n")

credits_missing = credits.isnull().sum()

print(credits_missing)
# Out:
# Missing Values in Titles Dataset:
#
# id                         0
# title                      0
# type                       0
# description              119
# release_year               0
# age_certification       6484
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 8511
# imdb_id                  667
# imdb_score              1021
# imdb_votes              1031
# tmdb_popularity          547
# tmdb_score              2080
# dtype: int64
#
# --------------------------------------
#
# Missing Values in Credits Dataset:
#
# person_id        0
# id               0
# name             0
# character    16277
# role             0
# dtype: int64

# %%
#step1-Handle the missing values in Titles Datset


# Fill description (text column)
titles['description'] = titles['description'].fillna(
    "No description available"
)

# Fill age certification (categorical column)
titles['age_certification'] = titles[
    'age_certification'
].fillna(
    "Not Rated"
)

# Fill seasons (numerical but applicable mainly for TV Shows)
titles['seasons'] = titles['seasons'].fillna(0)

# Fill numerical columns using median

titles['imdb_score'] = titles['imdb_score'].fillna(
    titles['imdb_score'].median()
)

titles['imdb_votes'] = titles['imdb_votes'].fillna(
    titles['imdb_votes'].median()
)

titles['tmdb_popularity'] = titles[
    'tmdb_popularity'
].fillna(
    titles['tmdb_popularity'].median()
)

titles['tmdb_score'] = titles['tmdb_score'].fillna(
    titles['tmdb_score'].median()
)


# Step 2 — Handle Missing Values in Credits Dataset

credits['character'] = credits['character'].fillna(
    "Unknown"
)


print("Missing values handled successfully!")
# Out:
# Missing values handled successfully!

# %%
#since we saw missing values so we are ready to handle the missing values
# Missing Values/Null Values Count
# Missing values in titles dataset
print("Missing Values in Titles Dataset:\n")

titles_missing = titles.isnull().sum()

print(titles_missing)

print("\n--------------------------------------\n")

# Missing values in credits dataset
print("Missing Values in Credits Dataset:\n")

credits_missing = credits.isnull().sum()

print(credits_missing)
# Out:
# Missing Values in Titles Dataset:
#
# id                        0
# title                     0
# type                      0
# description               0
# release_year              0
# age_certification         0
# runtime                   0
# genres                    0
# production_countries      0
# seasons                   0
# imdb_id                 667
# imdb_score                0
# imdb_votes                0
# tmdb_popularity           0
# tmdb_score                0
# dtype: int64
#
# --------------------------------------
#
# Missing Values in Credits Dataset:
#
# person_id    0
# id           0
# name         0
# character    0
# role         0
# dtype: int64

# %%
#STep2: fix Data Types:
# Convert Seasons to Integer
# ============================================

titles['seasons'] = titles['seasons'].astype(int)

print("Seasons column converted to integer.")
# Out:
# Seasons column converted to integer.

# %%
titles['seasons'].dtype
# Out:
# dtype('int64')

# %%
titles['seasons'].unique()
# Out:
# array([26,  0, 18,  9, 31,  6, 12, 49,  3, 11, 51, 22,  8,  2,  4,  1,  7,
#        16, 24, 35,  5, 34, 13, 15, 42, 33, 10, 25, 14, 19, 21, 17, 28])

# %%
titles['genres'].unique()
# Out:
# array(["['comedy', 'family', 'animation', 'action', 'fantasy', 'horror']",
#        "['action', 'drama', 'war', 'western', 'comedy', 'european']",
#        "['romance', 'war', 'drama']", ...,
#        "['drama', 'family', 'thriller']",
#        "['thriller', 'western', 'comedy']",
#        "['comedy', 'action', 'family']"], shape=(2028,), dtype=object)

# %%
# Clean 'genres' Column Properly

import ast

# Convert string list → actual list

titles['genres'] = titles['genres'].apply(
    lambda x: ast.literal_eval(x)
)

print("Genres column converted to list successfully.")
# Out:
# Genres column converted to list successfully.

# %%
titles['genres'].head()
# Out:
# 0    [comedy, family, animation, action, fantasy, h...
# 1      [action, drama, war, western, comedy, european]
# 2                                [romance, war, drama]
# 3                             [comedy, drama, romance]
# 4                           [thriller, drama, romance]
# Name: genres, dtype: object

# %%
# Clean 'production_countries' Column

# Convert string list → actual list

titles['production_countries'] = titles[
    'production_countries'
].apply(
    lambda x: ast.literal_eval(x)
)

print("Production countries converted to list successfully.")
# Out:
# Production countries converted to list successfully.

# %%
titles['production_countries'].head()
# Out:
# 0    [US]
# 1    [US]
# 2    [US]
# 3    [US]
# 4    [US]
# Name: production_countries, dtype: object

# %% [markdown]
# ##EXPLODE GENRES AND PRODUCTION_COUNTRIES since they will be helpful in Multivariate Analysis

# %%
#step3: Explode genres Column : Means row1->[comedy,drama] after exploding
#row1->comedy row2->drama  means one row per genre
# Create new dataframe with exploded genres

titles_genres = titles.explode('genres')

print("Genres exploded successfully.")
# Out:
# Genres exploded successfully.

# %%
titles_genres[['title','genres']].head(10)
# Out:
#                title     genres
# 0  The Three Stooges     comedy
# 0  The Three Stooges     family
# 0  The Three Stooges  animation
# 0  The Three Stooges     action
# 0  The Three Stooges    fantasy
# 0  The Three Stooges     horror
# 1        The General     action
# 1        The General      drama
# 1        The General        war
# 1        The General    western

# %%
# Explode Production Countries Column
# Create new dataframe

titles_countries = titles.explode(
    'production_countries'
)

print("Production countries exploded successfully.")
# Out:
# Production countries exploded successfully.

# %%
titles_countries[
    ['title','production_countries']
].head(10)
# Out:
#                          title production_countries
# 0            The Three Stooges                   US
# 1                  The General                   US
# 2  The Best Years of Our Lives                   US
# 3              His Girl Friday                   US
# 4            In a Lonely Place                   US
# 5                   Stagecoach                   US
# 6        It's a Wonderful Life                   US
# 7                       Detour                   US
# 8               My Man Godfrey                   US
# 9                    Marihuana                   US

# %% [markdown]
# ##Feature Engineering

# %% [markdown]
# #Feature 1:Instead of analyzing 110 years, we analyze decades.

# %%
# Create decade column

titles['decade'] = (titles['release_year'] // 10) * 10

print("Decade column created successfully.")
# Out:
# Decade column created successfully.

# %%
titles[['release_year','decade']].head(10)
# Out:
#    release_year  decade
# 0          1934    1930
# 1          1926    1920
# 2          1946    1940
# 3          1940    1940
# 4          1950    1950
# 5          1939    1930
# 6          1946    1940
# 7          1945    1940
# 8          1936    1930
# 9          1936    1930

# %% [markdown]
# #Feature 2: We create Short ,Medium Long Based on Runtime Category

# %%
# Create runtime category

def runtime_category(x):

    if x < 60:
        return "Short"

    elif x < 120:
        return "Medium"

    else:
        return "Long"


titles['runtime_category'] = titles['runtime'].apply(runtime_category)

print("Runtime category created successfully.")
# Out:
# Runtime category created successfully.

# %%
titles[['runtime','runtime_category']].head()
# Out:
#    runtime runtime_category
# 0       19            Short
# 1       78           Medium
# 2      171             Long
# 3       92           Medium
# 4       94           Medium

# %% [markdown]
# ##Feature 3: We categorize IMDb Scores into Low,Average,High

# %%
# Feature Engineering — Rating Category

def rating_category(x):

    if x < 5:
        return "Low"

    elif x < 7:
        return "Average"

    else:
        return "High"


titles['rating_category'] = titles[
    'imdb_score'
].apply(rating_category)

print("Rating category created successfully.")
# Out:
# Rating category created successfully.

# %%
titles[['imdb_score','rating_category']].head(10)
# Out:
#    imdb_score rating_category
# 0         8.6            High
# 1         8.2            High
# 2         8.1            High
# 3         7.8            High
# 4         7.9            High
# 5         7.8            High
# 6         8.6            High
# 7         7.3            High
# 8         8.0            High
# 9         4.0             Low

# %% [markdown]
# ##OUTLIER CHECKING: First we check for  runtime

# %%
plt.figure(figsize=(10,5))

sns.boxplot(
    x=titles['runtime']
)

plt.title("Boxplot of Runtime")

plt.show()

# %% [markdown]
# ### Why did you pick the specific chart?
#
# A boxplot was selected to detect outliers in the runtime variable. Boxplots are useful for identifying extreme values and understanding the spread of numerical data.
#
# ### What is/are the insight(s) found from the chart?
#
# The boxplot shows that most runtime values lie within a reasonable range; however, several high runtime values appear as outliers, especially beyond 200 minutes. These may represent unusually long movies or special content.
#
# ### Will the gained insights help creating a positive business impact?
#
# Yes. Identifying outliers helps ensure that unusually long runtimes do not distort statistical analysis or visualizations. Proper handling of these values improves data reliability and supports better decision-making related to content duration trends.

# %% [markdown]
# ##checking for IMDb Score Boxplot

# %%
plt.figure(figsize=(10,5))

sns.boxplot(x=titles['imdb_score'])

plt.title("Boxplot of IMDb Score")

plt.show()

# %%
#FOr IMDb Votes Boxplot
plt.figure(figsize=(10,5))

sns.boxplot(x=titles['imdb_votes'])

plt.title("Boxplot of IMDb Votes")

plt.show()

# %%
#For TMDB popularity
sns.boxplot(x=titles['tmdb_popularity'])
# Out:
# <Axes: xlabel='tmdb_popularity'>

# %%
sns.boxplot(x=titles['tmdb_score'])
# Out:
# <Axes: xlabel='tmdb_score'>

# %% [markdown]
# ## Outlier Handling Conclusion
#
# After analyzing numerical variables using boxplots, several outliers were identified across columns such as runtime, imdb_votes, tmdb_popularity, imdb_score, and tmdb_score.
#
# However, these outliers represent valid real-world values such as highly popular movies, extremely long content, or very high-rated titles. Therefore, removing these outliers would result in loss of valuable information.
#
# Based on this analysis, all outliers were retained to preserve the natural variability of the dataset and ensure meaningful insights during further analysis.

# %% [markdown]
# ##DATA MERGING: TITLES AND CREDITS

# %%
# ============================================
# Data Merging: Titles + Credits
# ============================================

# Merge datasets using 'id'

merged_df = titles.merge(
    credits,
    on='id',
    how='inner'
)

# Check merged dataset

print("Merged Dataset Shape:", merged_df.shape)

merged_df.head()
# Out:
# Merged Dataset Shape: (124179, 22)
#         id              title   type  \
# 0  ts20945  The Three Stooges   SHOW
# 1  ts20945  The Three Stooges   SHOW
# 2  ts20945  The Three Stooges   SHOW
# 3  tm19248        The General  MOVIE
# 4  tm19248        The General  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  The Three Stooges were an American vaudeville ...          1934
# 2  The Three Stooges were an American vaudeville ...          1934
# 3  During America’s Civil War, Union spies steal ...          1926
# 4  During America’s Civil War, Union spies steal ...          1926
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1             TV-PG       19
# 2             TV-PG       19
# 3         Not Rated       78
# 4         Not Rated       78
#
#                                               genres production_countries  \
# ...

# %% [markdown]
# ### Data Merging
#
# The titles dataset was merged with the credits dataset using the common column **'id'**.
# This merging integrates title-level information such as genre, runtime, and ratings with actor and director details.
#
# The merged dataset enables additional analysis such as:
#
# - Identifying most active actors
# - Identifying most active directors
# - Understanding participation trends
# - Evaluating role distribution

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# ## What all manipulations have you done and insights you found?
#
# Several data manipulation and preprocessing steps were performed to prepare the dataset for analysis and visualization.
#
# ### Data Cleaning and Manipulation Steps Performed
#
# 1. **Handled Missing Values**
#
# Missing values were identified using summary statistics and visualization techniques. Appropriate methods were applied to handle missing data:
#
# - The **description** column was filled with "No description available" since it contains textual data.
# - The **age_certification** column was filled with "Not Rated" to handle missing categorical values.
# - The **seasons** column was filled with 0, assuming missing values correspond to movies that do not have seasons.
# - Numerical columns such as **imdb_score**, **imdb_votes**, **tmdb_popularity**, and **tmdb_score** were filled using median values to maintain statistical consistency.
# - The **character** column in the credits dataset was filled with "Unknown".
# - The **imdb_id** column was left unchanged since it is an identifier and not required for analysis.
#
# ---
#
# 2. **Data Type Correction**
#
# The **seasons** column was converted from float to integer format to ensure logical correctness, as the number of seasons should always be a whole number.
#
# ---
#
# 3. **Cleaning Multi-Value Columns**
#
# The **genres** and **production_countries** columns contained list-like values stored as strings. These were converted into proper Python lists using appropriate parsing techniques.
#
# This step ensured that genre and country information could be analyzed correctly.
#
# ---
#
# 4. **Exploding Multi-Value Columns**
#
# The **genres** column was exploded so that each genre appears in a separate row. Similarly, the **production_countries** column was exploded to allow proper country-level analysis.
#
# This step enabled accurate frequency-based visualizations for genres and production countries.
#
# ---
#
# 5. **Duplicate Handling**
#
# Duplicate rows were identified and removed to ensure data integrity and prevent repeated records from affecting the analysis.
#
# ---
#
# 6. **Outlier Detection**
#
# Outliers were detected in numerical columns such as:
#
# - runtime
# - imdb_score
# - imdb_votes
# - tmdb_popularity
# - tmdb_score
#
# Boxplots were used to visually identify extreme values.
#
# After analysis, the outliers were retained because they represented valid real-world data such as highly popular movies or unusually long content.
#
# ---
#
# ### Key Insights Found During Data Preparation
#
# Several important insights were identified during the data manipulation process:
#
# - A large number of missing values were found in the **seasons** column, confirming that many records correspond to movies rather than TV shows.
# - The **age_certification** column contained many missing values, indicating that certification information may not be available for all titles.
# - The dataset contains multiple genres and production countries per title, showing high content diversity.
# - Numerical variables such as IMDb votes and TMDB popularity showed strong right-skewed distributions, indicating that a small number of titles receive very high popularity.
#
# Overall, these preprocessing steps improved data quality and ensured that the dataset became structured, clean, and suitable for reliable visualization and analysis.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code(Movie vs SHows) Following UBM rule:

plt.figure(figsize=(8,5))

sns.countplot(
    x='type',
    data=titles,
    palette='Set2'
)

plt.title("Distribution of Movies vs TV Shows")

plt.xlabel("Content Type")

plt.ylabel("Count")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A countplot was selected to visualize the distribution of content types because it is ideal for showing the frequency of categorical variables. This chart helps in understanding how many movies and TV shows are available on the platform.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart clearly shows that Movies dominate the Amazon Prime Video platform compared to TV Shows. The number of Movies is significantly higher than the number of TV Shows, indicating that the platform focuses more on movie content than episodic content. This imbalance suggests that Movies are the primary form of entertainment available on the platform.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. This insight can help stakeholders understand the current content distribution strategy of the platform. Since Movies dominate significantly, Amazon Prime Video may consider increasing the number of TV Shows to balance content diversity and attract viewers who prefer episodic content.
#
# A potential negative insight is that over-reliance on Movies may limit audience engagement for users who prefer long-term series content. Increasing TV Show production could help improve viewer retention and subscription growth.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code(Content Growth over Time)
plt.figure(figsize=(12,6))

titles['release_year'].value_counts().sort_index().plot()

plt.title("Number of Titles Released Per Year")

plt.xlabel("Release Year")

plt.ylabel("Number of Titles")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line plot was selected to visualize the trend in the number of titles released over time. Line charts are ideal for showing changes across continuous variables such as years and help identify growth patterns and fluctuations in content production.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows a steady increase in the number of titles released over the years, with a significant rise after the year 2000. The growth becomes especially rapid after 2015, indicating a major expansion in content production.
#
# The highest number of titles appears between 2018 and 2021, suggesting peak content production during recent years. The sudden drop observed in the last year may be due to incomplete data or ongoing content updates.
#
# Overall, the platform shows strong growth in content availability over time.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Understanding content growth trends helps stakeholders identify periods of expansion and evaluate content production strategies. The rapid growth observed after 2015 indicates increased investment in content creation.
#
# A potential negative insight is the sudden drop in recent years, which may indicate incomplete data or reduced production. If this trend continues, it could impact platform competitiveness and subscriber growth.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization (runtime of content)


plt.figure(figsize=(10,6))

sns.histplot(
    titles['runtime'],
    bins=30,
    kde=True
)

plt.title("Distribution of Runtime")

plt.xlabel("Runtime (minutes)")

plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram with KDE (Kernel Density Estimation) was selected to visualize the distribution of runtime values. Histograms are ideal for understanding how numerical data is distributed, identifying common ranges, and detecting skewness or unusual values in runtime duration.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that most titles have runtime durations between 80 and 120 minutes, indicating that medium-length content is the most common on the platform. The distribution is slightly right-skewed, meaning that there are some titles with longer runtimes, but they occur less frequently.
#
# Very few titles exceed 200 minutes, suggesting that extremely long content is rare. Short-duration content below 60 minutes is also less common compared to medium-length content.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Understanding runtime distribution helps content creators and platform managers optimize content length based on viewer preferences. Since most content falls within the medium runtime range (80–120 minutes), producing content within this range may improve viewer engagement and satisfaction.
#
# A potential negative insight is that extremely long content may reduce viewer engagement if audiences prefer shorter viewing durations. Monitoring runtime trends can help maintain optimal content length strategies.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code(IMDb Score Distribution)

plt.figure(figsize=(10,6))

sns.histplot(
    titles['imdb_score'],
    bins=20,
    kde=True
)

plt.title("Distribution of IMDb Scores")

plt.xlabel("IMDb Score")

plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram with KDE was selected to visualize the distribution of IMDb scores because it effectively shows how ratings are spread across different score ranges. This chart helps identify common rating ranges and overall content quality patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that most IMDb scores are concentrated between 5 and 7, indicating that the majority of titles have average to moderately good ratings. Very few titles have extremely low ratings below 3 or very high ratings above 9.
#
# The distribution appears approximately bell-shaped, suggesting that most content performs within a standard rating range, with fewer extreme cases.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Understanding rating distribution helps stakeholders evaluate overall content quality. Since most titles fall within the average rating range, improving content quality could shift more titles into the higher rating category.
#
# A potential negative insight is that a large number of average-rated titles may indicate limited exceptional content. Increasing the production of high-quality titles could improve brand reputation and viewer satisfaction.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code(TMDb Score)
plt.figure(figsize=(10,6))

sns.histplot(
    titles['tmdb_score'],
    bins=20,
    kde=True,
    color='green'
)

plt.title("Distribution of TMDB Scores")

plt.xlabel("TMDB Score")

plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram with KDE was selected to visualize the distribution of TMDB scores because it clearly shows how rating values are spread across titles. This chart helps identify common score ranges and detect overall content quality trends.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that most TMDB scores are concentrated between 5 and 7, indicating that the majority of titles have average ratings. Very few titles have extremely low scores below 3 or extremely high scores above 9.
#
# The distribution appears slightly bell-shaped, suggesting that most content performs within a moderate rating range with fewer extreme cases.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Understanding TMDB rating distribution helps stakeholders evaluate the overall quality of content available on the platform. Since most titles fall within average rating ranges, improving content quality could increase the number of highly rated titles, improving viewer satisfaction and platform reputation.
#
# A potential negative insight is that a large number of moderately rated titles may indicate limited exceptional content, which could affect audience retention if not improved.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code(using the exploded dataset and visualize top 10 genre distrib)

plt.figure(figsize=(12,6))

top_genres = (
    titles_genres['genres']
    .value_counts()
    .head(10)
)

sns.barplot(
    x=top_genres.values,
    y=top_genres.index,
    palette='viridis'
)

plt.title("Top 10 Most Common Genres")

plt.xlabel("Number of Titles")

plt.ylabel("Genres")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart was selected to visualize the distribution of genres because it effectively displays categorical data with many categories. This chart makes it easy to compare the frequency of different genres and identify the most common ones on the platform.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that Drama is the most dominant genre on Amazon Prime Video, significantly higher than all other genres. Comedy is the second most common genre, followed by Thriller and Action.
#
# Genres such as Romance, Crime, and Documentation also appear frequently but at lower levels compared to Drama and Comedy. Family and European genres have the lowest representation among the top 10 genres.
#
# This indicates that the platform strongly focuses on drama-based content, suggesting that audiences may have a strong preference for storytelling-oriented content.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Understanding the most common genres helps stakeholders identify audience preferences and plan content investments accordingly. Since Drama and Comedy dominate, increasing production in these genres could maintain viewer engagement.
#
# A potential negative insight is that certain genres such as Family and European content are less represented. This may limit audience diversity and reduce engagement from viewers who prefer niche or regional content. Expanding underrepresented genres could help attract a wider audience.

# %% [markdown]
# #### CHART 7 - BIVARIATE ANALYSIS STARTS

# %%
# Chart - 7 visualization code(RUNTIME VS CONTENT TYPE)

plt.figure(figsize=(10,6))

sns.boxplot(
    x='type',
    y='runtime',
    data=titles,
    palette='Set2'
)

plt.title("Runtime Distribution by Content Type")

plt.xlabel("Content Type")

plt.ylabel("Runtime")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A boxplot was selected to compare runtime distribution between Movies and TV Shows because boxplots effectively display differences in median values, spread, and outliers across categories. This helps in understanding how runtime varies between different content types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that Movies generally have significantly longer runtimes compared to TV Shows. The median runtime for Movies appears to be around 90 minutes, while TV Shows have much shorter runtimes, typically around 30–40 minutes.
#
# Movies also display a wider spread in runtime values, with several extreme outliers representing very long movies. TV Shows have relatively consistent runtime durations with fewer extreme variations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Understanding runtime differences between Movies and TV Shows helps content creators optimize production strategies. Since Movies typically require longer durations, resource planning and scheduling can be better managed.
#
# A potential negative insight is that extremely long movies may reduce viewer engagement if audiences prefer shorter content. Monitoring runtime trends can help maintain optimal content duration strategies.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 : IMDb Score by Content Type


plt.figure(figsize=(10,6))

sns.boxplot(
    x='type',
    y='imdb_score',
    data=titles,
    palette='coolwarm'
)

plt.title("IMDb Score Distribution by Content Type")

plt.xlabel("Content Type")

plt.ylabel("IMDb Score")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A boxplot was selected to compare IMDb score distributions between Movies and TV Shows because it effectively shows differences in median ratings, spread, and outliers across content types. This allows clear comparison of audience ratings between Movies and Shows.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that TV Shows generally have slightly higher IMDb scores compared to Movies. The median rating for TV Shows appears higher than that of Movies, indicating better average viewer ratings.
#
# Movies show a wider spread in IMDb scores with more low-rating outliers, suggesting that some movies receive significantly lower ratings. TV Shows appear to maintain more consistent rating levels compared to Movies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Understanding rating differences between Movies and TV Shows helps stakeholders evaluate content performance. Since TV Shows tend to receive slightly higher ratings, investing more in TV Show production could improve viewer satisfaction and engagement.
#
# A potential negative insight is that Movies show more variability and lower-rated outliers, which may affect platform reputation if poor-quality movies increase. Improving movie quality standards may help enhance audience trust.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code(RUNTIME VS IMDB SCORE)


plt.figure(figsize=(10,6))

sns.scatterplot(
    x='runtime',
    y='imdb_score',
    data=titles,
    alpha=0.5
)

plt.title("Runtime vs IMDb Score")

plt.xlabel("Runtime")

plt.ylabel("IMDb Score")

plt.show()

# %%
sns.scatterplot(x='runtime', y='imdb_score', data=titles)
# Out:
# <Axes: xlabel='runtime', ylabel='imdb_score'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot was selected to analyze the relationship between runtime and IMDb score because scatter plots are ideal for identifying patterns, trends, and correlations between two numerical variables. This chart helps determine whether runtime length influences viewer ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The scatter plot shows that most titles are concentrated between runtimes of 60 to 150 minutes, with IMDb scores mostly ranging between 4 and 8. There is no strong visible correlation between runtime and IMDb score, indicating that longer runtime does not necessarily lead to higher ratings.
#
# Both short and long runtime titles receive a wide range of ratings, suggesting that factors other than runtime, such as story quality or production value, likely influence ratings more significantly.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. This insight helps stakeholders understand that increasing runtime alone does not guarantee better audience ratings. Content creators should focus more on improving storytelling quality rather than simply increasing duration.
#
# A potential negative insight is that producing very long content without quality improvement may increase production costs without improving viewer satisfaction.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code(IMDb Score vs TMDB Score)


plt.figure(figsize=(10,6))

sns.scatterplot(
    x='imdb_score',
    y='tmdb_score',
    data=titles,
    alpha=0.5
)

plt.title("IMDb Score vs TMDB Score")

plt.xlabel("IMDb Score")

plt.ylabel("TMDB Score")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot was selected to analyze the relationship between IMDb scores and TMDB scores because scatter plots are ideal for identifying correlations between two numerical variables. This chart helps determine whether ratings from different platforms follow similar trends.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The scatter plot shows a strong positive correlation between IMDb scores and TMDB scores. As IMDb scores increase, TMDB scores also tend to increase, indicating consistency between the two rating platforms.
#
# Most titles are clustered between scores of 4 to 8 on both platforms, suggesting that the majority of content receives moderate ratings. Very few titles appear in extreme rating regions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The scatter plot shows a strong positive correlation between IMDb scores and TMDB scores. As IMDb scores increase, TMDB scores also tend to increase, indicating consistency between the two rating platforms.
#
# Most titles are clustered between scores of 4 to 8 on both platforms, suggesting that the majority of content receives moderate ratings. Very few titles appear in extreme rating regions.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 : Top Production Countries

plt.figure(figsize=(12,6))

top_countries = (
    titles_countries['production_countries']
    .value_counts()
    .head(10)
)

sns.barplot(
    x=top_countries.values,
    y=top_countries.index,
    palette='magma'
)

plt.title("Top 10 Production Countries")

plt.xlabel("Number of Titles")

plt.ylabel("Country")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart was selected to visualize the distribution of production countries because it allows easy comparison of categorical data with multiple categories. This chart helps identify the countries producing the highest number of titles on the platform.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that the United States (US) dominates content production by a very large margin compared to all other countries. India (IN) and the United Kingdom (GB) are the second and third largest contributors, but their counts are significantly lower than the US.
#
# Other countries such as Canada (CA), France (FR), Japan (JP), and Australia (AU) contribute smaller portions of content. This indicates that the platform relies heavily on US-based production while maintaining moderate contributions from international markets.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Understanding production country distribution helps stakeholders identify dominant content markets and evaluate opportunities for regional expansion. Since the US dominates production, increasing investment in international content markets such as India and Europe may help diversify content and attract global audiences.
#
# A potential negative insight is the heavy reliance on US-based production, which may limit content diversity and reduce engagement among international viewers. Expanding production across more regions could improve audience reach and platform growth.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 : Content Growth by Type Over Years

plt.figure(figsize=(12,6))

content_trend = (
    titles
    .groupby(['release_year', 'type'])
    .size()
    .unstack()
)

content_trend.plot()

plt.title("Content Growth by Type Over Years")

plt.xlabel("Release Year")

plt.ylabel("Number of Titles")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line chart was selected to visualize content growth trends over time because it effectively shows how the number of Movies and TV Shows has changed across different years. Line charts are ideal for identifying growth patterns and comparing trends between categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# A line chart was selected to visualize content growth trends over time because it effectively shows how the number of Movies and TV Shows has changed across different years. Line charts are ideal for identifying growth patterns and comparing trends between categories.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Understanding content growth trends helps stakeholders evaluate production strategies and identify periods of rapid expansion. The strong growth in Movies suggests continued investment in film production, while the gradual rise in TV Shows indicates growing interest in episodic content.
#
# A potential negative insight is that TV Shows have grown at a slower pace than Movies, which may limit viewer engagement among audiences who prefer long-term series. Increasing TV Show production could improve subscriber retention and engagement.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 : Genre vs IMDb Score


plt.figure(figsize=(12,6))

# Calculate average IMDb score per genre

top_genre_rating = (
    titles_genres
    .groupby('genres')['imdb_score']
    .mean()
    .sort_values(ascending=False)
    .head(10)
)

# Plot

sns.barplot(
    x=top_genre_rating.values,
    y=top_genre_rating.index,
    palette='coolwarm'
)

plt.title("Average IMDb Score by Genre")

plt.xlabel("Average IMDb Score")

plt.ylabel("Genres")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was selected to visualize the average IMDb score across genres because it allows easy comparison of numerical values across multiple categories. This helps identify which genres consistently receive higher audience ratings and which genres perform relatively lower.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that Documentary is the highest-rated genre, followed by History and Reality genres. These genres consistently receive higher average IMDb scores compared to others.
#
# Genres such as Animation, Sport, and War also maintain relatively strong ratings, while genres like Drama and Family appear slightly lower in comparison.
#
# This suggests that informational and real-world content such as documentaries and historical content tends to receive better audience ratings than general entertainment genres.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Identifying highly rated genres helps stakeholders prioritize investment in content categories that consistently perform well. Since Documentary and History genres receive higher ratings, increasing production in these genres may improve viewer satisfaction and platform reputation.
#
# A potential negative insight is that lower-rated genres may require improvement in storytelling quality or production techniques to maintain viewer interest and competitiveness.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Chart - 14 : Correlation Heatmap
# ============================================

plt.figure(figsize=(10,8))

# Select numerical columns

numeric_cols = titles.select_dtypes(
    include=['int64','float64']
)

# Compute correlation matrix

corr_matrix = numeric_cols.corr()

# Plot heatmap

sns.heatmap(
    corr_matrix,
    annot=True,
    cmap='coolwarm',
    fmt=".2f"
)

plt.title("Correlation Heatmap of Numerical Variables")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap was selected to visualize relationships between multiple numerical variables simultaneously. Heatmaps are effective for identifying strong, moderate, and weak correlations across several variables, making them ideal for multivariate analysis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap shows a strong positive correlation between IMDb score and TMDB score (approximately 0.49), indicating that titles receiving higher ratings on IMDb also tend to receive higher ratings on TMDB.
#
# A very strong correlation is observed between release_year and decade (approximately 0.99), which is expected because the decade variable was derived from release_year.
#
# Runtime shows a slight negative correlation with seasons (-0.32), suggesting that longer runtimes are more associated with movies, while shows typically have shorter episode durations.
#
# Most other variables show weak correlations, indicating that individual features such as runtime and popularity have limited direct relationships with ratings.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Chart - 15 : Pair Plot

# Select important numerical columns

selected_cols = [
    'runtime',
    'imdb_score',
    'tmdb_score',
    'tmdb_popularity',
    'imdb_votes'
]

sns.pairplot(
    titles[selected_cols],
    diag_kind='kde'
)

plt.suptitle(
    "Pair Plot of Numerical Variables",
    y=1.02
)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot was selected to visualize relationships between multiple numerical variables simultaneously. Pair plots allow visualization of distributions along the diagonal and pairwise relationships between variables, making them useful for multivariate analysis and identifying correlations and patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pair plot shows a noticeable positive relationship between IMDb scores and TMDB scores, confirming consistency between rating platforms. Titles with higher IMDb scores generally also have higher TMDB scores.
#
# Runtime appears widely distributed but does not show a strong relationship with ratings, indicating that longer duration does not necessarily result in better ratings.
#
# TMDB popularity and IMDb votes show skewed distributions, with a small number of titles receiving extremely high popularity and vote counts. This indicates that only a few titles achieve very high audience engagement.

# %% [markdown]
# ##Merged Data Analysis

# %%
# Additional Chart 1: Top 10 Actors


plt.figure(figsize=(12,6))

top_actors = (
    merged_df[
        merged_df['role'] == 'ACTOR'
    ]['name']
    .value_counts()
    .head(10)
)

sns.barplot(
    x=top_actors.values,
    y=top_actors.index,
    palette='viridis'
)

plt.title("Top 10 Actors by Number of Titles")

plt.xlabel("Number of Titles")

plt.ylabel("Actor Name")

plt.show()

# %% [markdown]
# why did i pick this?
#
#
# The chart shows that George 'Gabby' Hayes appears in the highest number of titles, followed by Roy Rogers and Bess Flowers. These actors have significantly higher participation compared to others.
#
# Several actors appear consistently across many titles, indicating repeated collaboration or frequent casting patterns within the platform's content library.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that George 'Gabby' Hayes appears in the highest number of titles, followed by Roy Rogers and Bess Flowers. These actors have significantly higher participation compared to others.
#
# Several actors appear consistently across many titles, indicating repeated collaboration or frequent casting patterns within the platform's content library.

# %% [markdown]
# Insights??
#
#
# Yes. Identifying frequently appearing actors helps stakeholders understand talent utilization and casting trends. Popular or frequently appearing actors may attract loyal audiences and contribute to consistent viewer engagement.
#
# A potential negative insight is that relying heavily on a small group of actors may limit diversity in casting, which could reduce audience interest over time. Introducing new talent may help maintain content freshness.

# %%
#TOP DIRECTORS

plt.figure(figsize=(12,6))

top_directors = (
    merged_df[
        merged_df['role'] == 'DIRECTOR'
    ]['name']
    .value_counts()
    .head(10)
)

sns.barplot(
    x=top_directors.values,
    y=top_directors.index,
    palette='magma'
)

plt.title("Top 10 Directors by Number of Titles")

plt.xlabel("Number of Titles")

plt.ylabel("Director Name")

plt.show()

# %% [markdown]
# ###Insights
#
# The chart shows that Joseph Kane directed the highest number of titles, followed by Sam Newfield and Jay Chapman. These directors appear frequently across multiple titles, indicating strong involvement in content production.
#
# Several directors consistently appear across many titles, suggesting recurring collaborations or specialization in certain genres or content types.
#
# ##business Impact
#
# Yes. Identifying frequently contributing directors helps stakeholders understand leadership patterns in content creation. Experienced and frequently involved directors can be prioritized for future productions to maintain consistent content output.
#
# A potential negative insight is that repeated reliance on a limited number of directors may reduce creative diversity. Encouraging collaborations with new directors could introduce fresh storytelling styles.

# %%
# Additional Chart 3: Role Distribution


plt.figure(figsize=(8,5))

role_counts = merged_df['role'].value_counts()

sns.barplot(
    x=role_counts.index,
    y=role_counts.values,
    palette='Set2'
)

plt.title("Distribution of Roles (Actor vs Director)")

plt.xlabel("Role")

plt.ylabel("Count")

plt.show()

# %% [markdown]
# ##Reason to Pick chart?
#
# A bar chart was selected to visualize role distribution because it effectively compares categorical data. This chart helps understand the proportion of actors and directors present in the dataset.
#
# ##Insights?
#
# The chart shows that the number of actors is significantly higher than the number of directors. This indicates that each title typically involves multiple actors but usually only one or a few directors.
#
# The large difference between actor and director counts reflects the collaborative nature of film and television production, where many actors contribute to a single title.
#
# ##Impact
#
#
# Yes. Understanding role distribution helps stakeholders estimate workforce requirements for content production. Since actor participation is much higher, casting management and talent coordination become critical areas of focus.
#
# A potential negative insight is that managing large actor pools may increase production complexity and cost, requiring efficient scheduling and resource planning.

# %%
##Bivariate Analysis:
# Additional Chart 4: Role vs IMDb Score

plt.figure(figsize=(10,6))

sns.boxplot(
    x='role',
    y='imdb_score',
    data=merged_df,
    palette='coolwarm'
)

plt.title("IMDb Score Distribution by Role")

plt.xlabel("Role")

plt.ylabel("IMDb Score")

plt.show()

# %% [markdown]
# ##why this chart?
#
# A boxplot was selected to compare IMDb scores across roles because it helps visualize differences in score distributions between actors and directors. This allows comparison of how ratings vary across role participation.
#
# ##Insights?
#
#
# The chart shows that IMDb score distributions for actors and directors are very similar, with both roles having median scores around 6. This indicates that titles associated with both actors and directors receive comparable rating distributions.
#
# Both roles also show the presence of low-rating and high-rating outliers, suggesting that performance quality varies across productions regardless of role category.
#
#
# ##Impact?
#
# Yes. Understanding rating distributions across roles helps stakeholders evaluate the balance of contributions between actors and directors. Since both roles show similar rating patterns, maintaining strong collaboration between actors and directors is important for producing quality content.
#
# A potential negative insight is that variability in ratings across both roles suggests inconsistent production quality. Improving coordination and production standards may help stabilize rating outcomes.

# %%
##Multivariate Analysis
#Does having more actors improve Ratings?
# Count number of actors per title

actor_count = (
    merged_df[
        merged_df['role'] == 'ACTOR'
    ]
    .groupby('id')
    .size()
    .reset_index(name='actor_count')
)

# %%
actor_analysis = actor_count.merge(
    titles[['id','imdb_score']],
    on='id'
)

# %%
# ============================================
# Additional Chart 5: Actor Count vs IMDb Score
# ============================================

plt.figure(figsize=(10,6))

sns.scatterplot(
    x='actor_count',
    y='imdb_score',
    data=actor_analysis,
    alpha=0.5
)

plt.title("Actor Count vs IMDb Score")

plt.xlabel("Number of Actors")

plt.ylabel("IMDb Score")

plt.show()

# %% [markdown]
# ##WHy This PLOT?
#
# A scatter plot was selected to analyze the relationship between the number of actors and IMDb score because scatter plots effectively display patterns and relationships between two numerical variables. This helps determine whether cast size influences audience ratings.
#
# ##Insights??
#
# The scatter plot shows that most titles contain between 5 and 30 actors, with IMDb scores generally ranging between 4 and 8. Titles with both small and large numbers of actors receive varied ratings.
#
# There is no strong visible correlation between the number of actors and IMDb score, indicating that larger cast size does not necessarily result in better ratings.
#
#
# ##Impacts??
#
#
# Yes. This insight helps stakeholders understand that increasing cast size alone does not guarantee higher audience ratings. Instead, focusing on storytelling, direction quality, and production standards may have a greater impact on audience satisfaction.
#
# A potential negative insight is that unnecessarily large casts may increase production costs without improving ratings, highlighting the importance of efficient resource planning.

# %%
##ADD ACtor count to merged_df
merged_with_actor = merged_df.merge(
    actor_count,
    on='id',
    how='left'
)

# %%
# ============================================
# Correlation Heatmap - Merged Dataset
# ============================================

plt.figure(figsize=(12,8))

# Select numeric columns

merged_numeric = merged_with_actor.select_dtypes(
    include=['int64','float64']
)

# Compute correlation

corr_matrix = merged_numeric.corr()

# Plot heatmap

sns.heatmap(
    corr_matrix,
    annot=True,
    cmap='coolwarm',
    fmt=".2f"
)

plt.title("Correlation Heatmap of Merged Dataset")

plt.show()

# %% [markdown]
# ##WHy this plot??
#
# A correlation heatmap was selected to analyze relationships between multiple numerical variables in the merged dataset. This visualization helps identify strong, moderate, and weak relationships between production characteristics, actor participation, ratings, and popularity metrics simultaneously.
#
# ##Insights??
#
# The heatmap shows a strong positive correlation between IMDb score and TMDB score (approximately 0.60), indicating strong consistency between the two rating platforms.
#
# A moderate positive correlation is observed between IMDb votes and actor count (approximately 0.40), suggesting that titles with more actors may attract more audience attention and engagement.
#
# Runtime shows a slight negative correlation with seasons (-0.30), indicating that TV shows with multiple seasons typically have shorter episode durations compared to movies.
#
# A very strong correlation exists between release_year and decade (approximately 0.99), which is expected since the decade variable is derived from release year.
#
# Most other relationships show weak correlations, suggesting that audience ratings depend on multiple factors rather than a single dominant variable.
#
# ##Impact??
#
# Yes. Understanding relationships between actor participation, ratings, and popularity helps stakeholders identify factors influencing audience engagement. The strong correlation between IMDb and TMDB scores confirms the reliability of rating metrics across platforms.
#
# The moderate relationship between actor count and audience votes suggests that larger casts may attract viewer interest, but the weak correlation with ratings indicates that content quality remains the primary factor influencing audience satisfaction.
#
# These insights help guide production planning, casting decisions, and marketing strategies to optimize audience reach and content performance.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Based on the exploratory data analysis of Amazon Prime Video content, several strategic recommendations can be proposed to help achieve business objectives such as increasing viewer engagement, improving content quality, expanding audience reach, and optimizing production investment.
#
# ### 1. Increase Investment in High-Demand Genres
# The analysis revealed that Drama, Comedy, and Thriller are the most frequently produced genres, indicating strong viewer demand. Amazon Prime Video should continue investing in these genres to maintain viewer engagement and platform competitiveness. Additionally, producing innovative variations within these genres can help sustain audience interest.
#
# ### 2. Focus on High-Quality Informational Content
# Although Drama is the most common genre, Documentary and History genres showed higher average IMDb ratings. This suggests that audiences value informative and educational content. Increasing the production of documentaries, biographical films, and historical content can improve viewer satisfaction and enhance brand reputation.
#
# ### 3. Expand International Content Production
# The production country analysis showed that the United States dominates content production, while countries such as India, the United Kingdom, and Canada contribute moderate content volumes. Expanding production in emerging markets such as Asia, Europe, and Latin America can help attract diverse global audiences and increase regional subscriptions.
#
# ### 4. Strengthen Content Quality Over Quantity
# Correlation analysis showed that runtime length and cast size do not strongly influence ratings. This suggests that simply increasing runtime or cast size does not guarantee higher audience ratings. Instead, Amazon Prime Video should focus on improving storytelling, screenplay quality, direction, and production value.
#
# ### 5. Utilize Rating Metrics for Content Strategy
# Strong correlation between IMDb and TMDB scores confirms that ratings are reliable indicators of content performance. Amazon Prime Video should use audience rating data to identify successful content patterns and replicate similar themes, genres, and production strategies.
#
# ### 6. Optimize Talent Utilization and Casting Strategies
# Actor and director participation analysis showed repeated involvement of certain individuals across multiple titles. While experienced talent ensures production consistency, introducing new actors and directors can enhance creativity, innovation, and audience engagement.
#
# ### 7. Improve Marketing and Content Discoverability
# Popularity and vote analysis showed that only a limited number of titles receive very high engagement. This suggests that some content may not be reaching its target audience. Improving recommendation algorithms, targeted marketing campaigns, and personalized content suggestions can increase content visibility and viewer interaction.
#
# ### 8. Invest in TV Show Growth for Long-Term Engagement
# Trend analysis showed that Movies dominate the platform, while TV Shows are growing gradually. Increasing the production of high-quality TV series can improve viewer retention since episodic content encourages repeated platform usage.
#
# ### 9. Maintain Balanced Content Portfolio
# The platform should maintain a balanced mix of:
# - Popular genres (Drama, Comedy)
# - High-rated genres (Documentary, History)
# - Regional content
# - Experimental or niche content
#
# This strategy ensures diversity and reduces risk associated with over-dependence on a single content category.
#
# ### 10. Monitor Audience Trends Over Time
# Content growth analysis showed significant expansion after 2015. Continuous monitoring of release trends and audience preferences will help Amazon Prime Video adapt quickly to changing consumer behavior and industry competition.
#
# ---
#
# ### Overall Strategic Recommendation
#
# To achieve its business objectives, Amazon Prime Video should adopt a data-driven content strategy that prioritizes content quality, genre diversity, global expansion, and optimized talent management. By leveraging audience insights and production trends, the platform can improve viewer satisfaction, increase subscriber growth, and maintain a competitive advantage in the streaming industry.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This exploratory data analysis project provided a comprehensive understanding of Amazon Prime Video's content distribution, performance patterns, and production characteristics. By analyzing title-level and credit-level datasets, meaningful insights were generated regarding content growth, genre distribution, audience ratings, production regions, and talent participation.
#
# ### 1. Content Distribution and Platform Focus
# The analysis revealed that Movies dominate the platform compared to TV Shows, indicating a strong emphasis on film-based content production. However, TV Shows have shown gradual growth over recent years, especially after 2010, suggesting increasing audience demand for episodic and long-term content formats.
#
# ### 2. Rapid Growth in Content Production Over Time
# Trend analysis showed that the number of titles released has increased significantly over the past two decades, with particularly sharp growth observed after 2015. This reflects the rapid expansion of digital streaming platforms and growing competition within the entertainment industry.
#
# ### 3. Genre Popularity and Audience Preferences
# Genre distribution analysis identified Drama, Comedy, and Thriller as the most dominant genres on the platform. These genres likely reflect strong viewer demand for storytelling-based entertainment content. However, quality-based analysis revealed that Documentary and History genres achieved higher average IMDb scores, indicating strong audience appreciation for educational and informative content.
#
# ### 4. Regional Production Patterns
# The production country analysis demonstrated that the United States dominates content production, while countries such as India, the United Kingdom, and Canada contribute moderate levels of content. This highlights the platform's reliance on US-based production while also indicating potential opportunities for expanding international content.
#
# ### 5. Rating Consistency Across Platforms
# Correlation analysis revealed a strong positive relationship between IMDb scores and TMDB scores, confirming that audience ratings are consistent across different rating platforms. This consistency supports the reliability of using rating metrics to evaluate content performance.
#
# ### 6. Runtime and Content Performance Relationship
# The analysis showed that runtime length does not significantly influence content ratings. Both short and long-duration titles received a wide range of ratings, suggesting that content quality and storytelling are more important factors than duration alone.
#
# ### 7. Talent Participation and Collaboration Patterns
# Merged dataset analysis revealed that certain actors and directors appear frequently across multiple titles, indicating repeated collaborations and strong industry participation patterns. Additionally, the number of actors in a title did not strongly correlate with ratings, suggesting that increasing cast size does not guarantee better audience reception.
#
# ### 8. Audience Engagement and Popularity Patterns
# Popularity and vote analysis showed that only a small number of titles receive extremely high engagement levels, while the majority maintain moderate popularity. This indicates the importance of marketing, recommendation systems, and content visibility strategies.
#
# ---
#
# ### Overall Conclusion
#
# Overall, the exploratory data analysis provided valuable insights into how content characteristics, audience ratings, and production trends interact within the Amazon Prime Video ecosystem. The findings highlight that content quality, genre diversity, global production strategies, and effective talent management are critical factors influencing viewer satisfaction and platform growth.
#
# By leveraging these insights, stakeholders can make informed decisions regarding content investment, regional expansion, and audience engagement strategies. The results of this analysis demonstrate the importance of data-driven decision-making in maintaining competitiveness within the rapidly evolving streaming industry.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
